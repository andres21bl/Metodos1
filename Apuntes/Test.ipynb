# %%
a = 3
print(a)
np.sin(0)
# Out:
# 3
# 0.0

# %%
import numpy as np
import sympy as sp
print(a)
a = 4
# Out:
# 3

# %%
print(a)
# Out:
# 3

# %%
import matplotlib.pyplot as plt

plt.scatter([1,1],[1,2])
plt.savefig("graph.png")

# %%
#Esta celda define un linspace para hacer un gráfico de seno con 10000 puntos, entra a como la amplitud del seno a graficar.
#Se definen x y y variables que van a hacer tal cosa
x=np.linspace(0,10,int(1e4))
y=a*np.sin(x)
#y=np.linspace(-2,2,1000)
cosa_horrorosa="Pepe"
coef_Fourier_inv=3
print(x)
plt.plot(x,y)
# Out:
# [0.00000000e+00 1.00010001e-03 2.00020002e-03 ... 9.99799980e+00
#  9.99899990e+00 1.00000000e+01]
